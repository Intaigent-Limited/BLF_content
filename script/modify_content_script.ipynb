# %% [markdown]
# ## 1. Review the titles for both Swahili and English

# %%
# Extract top three levels of titles from blf_mobile_intaigent_english.json
# The output file should be a structured JSON file

import json

def extract_titles(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
        
    structured_titles = {}
    for level1, level1_content in data.items():
        structured_titles[level1] = {}
        for level2, level2_content in level1_content.items():
            structured_titles[level1][level2] = list(level2_content.keys())
    
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(structured_titles, f, indent=2, ensure_ascii=False)

if __name__ == '__main__':
    extract_titles('../blf_mobile_intaigent_english.json', 'structured_titles_english.json')
    print("Structured titles extracted and saved to structured_titles_english.json")

    extract_titles('../blf_mobile_intaigent_swahili.json', 'structured_titles_swahili.json')
    print("Structured titles extracted and saved to structured_titles_swahili.json")
# Out:
# Structured titles extracted and saved to structured_titles_english.json
# Structured titles extracted and saved to structured_titles_swahili.json

# %%
#load the structured titles
with open('structured_titles_english.json', 'r', encoding='utf-8') as f:
    structured_titles_english = json.load(f)

with open('structured_titles_swahili.json', 'r', encoding='utf-8') as f:
    structured_titles_swahili = json.load(f)

# Combine the two structured titles
structured_titles_combined = {}

for (level1_eng, level1_content_eng), (level1_swa, level1_content_swa) in zip(structured_titles_english.items(), structured_titles_swahili.items()):
    structured_titles_combined[f"{level1_eng} ({level1_swa})"] = {}
    
    for (level2_eng, level2_content_eng), (level2_swa, level2_content_swa) in zip(level1_content_eng.items(), level1_content_swa.items()):
        structured_titles_combined[f"{level1_eng} ({level1_swa})"][f"{level2_eng} ({level2_swa})"] = [
            f"{item_eng} ({item_swa})" 
            for item_eng, item_swa in zip(level2_content_eng, level2_content_swa)
        ]

# Print the first few items to check the structure
print(json.dumps(dict(list(structured_titles_combined.items())[:2]), indent=2, ensure_ascii=False))

with open('../structured_titles_combined.json', 'w', encoding='utf-8') as f:
    json.dump(structured_titles_combined, f, ensure_ascii=False, indent=2)
# Out:
# {
#   "successful ae operations, leadership and entrepreneurship (Operesheni za Wajisiriamali wa Kilimo ,Uongozi na Ujasiriamali)": {
#     "successful ae operations, leadership and entrepreneurship (Operesheni za Wajasiriamali wa Kilimo zilizofanikiwa ,Uongozi na Ujasiriamali)": [
#       "retailers and shops (Wauzaji reja reja na maduka)",
#       "entrepreneurship and leadership (ujasiriamali na uongozi)"
#     ]
#   },
#   "bookkeeping essentials (Misingi ya uhasibu)": {
#     "bookkeeping and your business (mahitaji ya uhasibu)": [
#       "what is bookkeeping (Uhasibu ni nini)",
#       "next steps for bookkeeping (hatua zinazofuata za uhasibu)"
#     ],
#     "bookkeeping ledgers (Leja za kihasibu)": [
#       "cash ledger part 1 (Daftari la fedha taslimu sehemu ya kwanza)",
#       "cash ledger part 2 (Daftari la fedha taslimu sehemu ya pili)",
#       "expense ledger (Daftari la Matumizi)",
#       "supplier ledger (Daftari la Wagavi)",
#       "sales and roleplay (mauzo na mchezo wa kuigiza)"
#     ]
#   }
# }

# %%
# erase the structured_titles swahili and english files to help version control
import os
os.remove('structured_titles_english.json')
os.remove('structured_titles_swahili.json')

# %% [markdown]
# ## 2. Review content for both Swahili and English.

# %%
# combine the full learning content of the two files, 

import json

# Load the English and Swahili content
with open('../blf_mobile_intaigent_english.json', 'r', encoding='utf-8') as f:
    english_content = json.load(f)

with open('../blf_mobile_intaigent_swahili.json', 'r', encoding='utf-8') as f:
    swahili_content = json.load(f)

combined_content = {}

for (level1_eng, level1_content_eng), (level1_swa, level1_content_swa) in zip(english_content.items(), swahili_content.items()):
    combined_content[f"{level1_eng} ({level1_swa})"] = {}
    
    for (level2_eng, level2_content_eng), (level2_swa, level2_content_swa) in zip(level1_content_eng.items(), level1_content_swa.items()):
        combined_content[f"{level1_eng} ({level1_swa})"][f"{level2_eng} ({level2_swa})"] = {}
        
        for (level3_eng, content_eng), (level3_swa, content_swa) in zip(level2_content_eng.items(), level2_content_swa.items()):
            combined_content[f"{level1_eng} ({level1_swa})"][f"{level2_eng} ({level2_swa})"][f"{level3_eng} ({level3_swa})"] = {
                "english": content_eng,
                "swahili": content_swa
            }

# Print the first few items to check the structure
print(json.dumps(dict(list(combined_content.items())[:1]), indent=2, ensure_ascii=False))

# Save the combined content
with open('blf_mobile_intaigent_combined.json', 'w', encoding='utf-8') as f:
    json.dump(combined_content, f, ensure_ascii=False, indent=2)

print("Combined content saved to blf_mobile_intaigent_combined.json")
# Out:
# {
#   "successful ae operations, leadership and entrepreneurship (Operesheni za Wajisiriamali wa Kilimo ,Uongozi na Ujasiriamali)": {
#     "successful ae operations, leadership and entrepreneurship (Operesheni za Wajasiriamali wa Kilimo zilizofanikiwa ,Uongozi na Ujasiriamali)": {
#       "retailers and shops (Wauzaji reja reja na maduka)": {
#         "english": {
#           "Welcome to our training session on Agribusiness Retail! Today, we'll explore the four types of retail stores and discover what makes a retailer successful.": {
#             "The diligence you put into your learning now is crafting the foundation for a thriving and innovative career in agribusiness—keep moving forward with determination.": [
#               {
#                 "mobile_summary_number": "1",
#                 "mobile_summary_final": "1st type: Basic Retailer - Operates at the minimum level just to stay in business, with no extra investment in inventory or growth initiatives."
#               },
#               {
#                 "mobile_summary_number": "2",
#                 "mobile_summary_final": "2nd type: Nearly Basic Retailer - Better than basic retailers, these stores manage improved operations and finances, with some ability to invest in growing their inventory."
#               },
#               {
#                 "mobile_summary_number": "3",
#                 "mobile_summary_final": "3rd type: Sustainable Retailer - Known for a reliable reputation with suppliers, these retailers can procure necessary inputs on seasonal credit terms."
#               },
#               {
#                 "mobile_summary_number": "4",
#                 "mobile_summary_final": "4th type: Mainstay Retailer - Maintains excellent credit terms with multiple suppliers, has a steady supply of inventory that meets market demands, and offers additional supplies and services."
#               },
#               {
#                 "mobile_summary_number": "5",
#                 "mobile_summary_final": "Key traits of successful retailers include a solid customer base, a good product mix, strong supplier relationships, strategic location, clear business vision, accurate financial management, frequent inventory turnover, and offering extra services like transportation."
#               },
#               {
#                 "mobile_summary_number": "6",
#                 "mobile_summary_final": "Remember, having a business vision is crucial. To stay ahead, always aim to improve and set clear goals for the future of your retail shop. This growth mindset is essential for outperforming competitors and securing customer loyalty."
#               },
#               {
#                 "mobile_summary_number": "7",
#                 "mobile_summary_final": "Congratulations, you have completed #PERCENT% of the successful ae operations, leadership and entrepreneurship category 👍"
#               }
#             ]
#           }
#         },
#         "swahili": {
#           "Karibu kwenye kipindi  chetu cha mafunzo kuhusu Biashara ya Kilimo! Leo, tutachunguza aina nne za wauza duka wa rejareja na kugundua kinachofanya mfanyabiashara wa rejareja kuwa na mafanikio.": {
#             "Bidii unayoweka katika kujifunza kwako sasa inaunda msingi wa kazi yenye kustawi na ubunifu katika biashara ya kilimo—endelea kusonga mbele kwa azma.": [
#               {
#                 "mobile_summary_number": "1",
#                 "mobile_summary_final": "Aina ya kwanza: Mfanyabiashara wa rejareja - Anafanya kazi ngazi ya chini kabisa ili kubaki katika biashara, bila uwekezaji wa ziada katika bidhaa au mipango ya ukuaji."
#               },
#               {
#                 "mobile_summary_number": "2",
#                 "mobile_summary_final": "Aina ya pili: Wauzaji Karibu wa Kawaida - Wakiwa bora zaidi ya wauzaji wa kawaida, maduka haya yanasimamia shughuli na fedha zilizoboreshwa, pamoja na uwezo fulani wa kuwekeza katika kuongeza hesabu yao."
#               },
#               {
#                 "mobile_summary_number": "3",
#                 "mobile_summary_final": "Aina ya 3: Wauzaji Endelevu - Wanajulikana kwa sifa ya kuaminika na wagavi, wauzaji hawa wanaweza kupata vifaa vinavyohitajika kwa masharti ya mikopo ya msimu."
#               },
#               {
#                 "mobile_summary_number": "4",
#                 "mobile_summary_final": "Aina ya Nne: Muuzaji Mkuu - Anadumisha masharti bora ya mikopo na wauzaji mbalimbali, anayo akiba thabiti ya bidhaa inayoendana na mahitaji ya soko, na pia anatoa vifaa na huduma za ziada."
#               },
#               {
#                 "mobile_summary_number": "5",
#                 "mobile_summary_final": "Sifa kuu za wauzaji wanye ufanisi ni pamoja na kuwa na msingi imara wa wateja, mchanganyiko mzuri wa bidhaa, uhusiano thabiti na wagavi, eneo la kimkakati, maono wazi ya biashara, usimamizi sahihi wa fedha, mzunguko wa mara kwa mara wa bidhaa, na kutoa huduma za ziada kama usafiri."
#               },
#               {
#                 "mobile_summary_number": "6",
#                 "mobile_summary_final": "Kumbuka, kuwa na maono ya biashara ni muhimu. Ili kubaki mbele, jitahidi daima kuboresha na kuweka malengo wazi kwa ajili ya mustakabali wa duka lako la rejareja. Mtazamo huu wa ukuaji ni muhimali ili kuwazidi washindani na kuhakikisha uaminifu kwa wateja."
#               },
#               {
#                 "mobile_summary_number": "7",
#                 "mobile_summary_final": "Hongera, umekamilisha #PERCENT% ya aina ya Operesheni za Wajasiriamali wa Kilimo zilizofanikiwa ,Uongozi na Ujasiriamali 👍"
#               }
#             ]
#           }
#         }
#       },
#       "entrepreneurship and leadership (ujasiriamali na uongozi)": {
#         "english": {
#           "Hi! Today we'll explore essential entrepreneurship and leadership skills critical to your success. We'll define entrepreneurship, discuss key entrepreneurial qualities, and dip into leadership development. Let's dive in!": {
#             "Every new lesson you embrace is a catalyst for future success in agribusiness—keep fueling your passion and drive.": [
#               {
#                 "mobile_summary_number": "1",
#                 "mobile_summary_final": "Entrepreneurship involves spotting market opportunities, strategizing, organizing resources, and investing for long-term benefits. An entrepreneur starts a business, takes risks, and aims for success by bringing innovative ideas to life."
#               },
#               {
#                 "mobile_summary_number": "2",
#                 "mobile_summary_final": "As entrepreneurs, key traits include: actively looking for growth opportunities, prioritizing efficiency, demanding quality, and maintaining cost-effectiveness. They’re also informed, strategic, goal-setters, planners, and persistent."
#               },
#               {
#                 "mobile_summary_number": "3",
#                 "mobile_summary_final": "Good entrepreneurs are confident and excellent listeners, understanding both customer and supplier needs. They’re decisive and capable of tough decision-making, motivating others towards success. Risk-taking and persuasiveness are also crucial."
#               },
#               {
#                 "mobile_summary_number": "4",
#                 "mobile_summary_final": "Turning to leadership, a good leader creates an inspiring future vision, motivates engagement, manages vision realization, and coaches the team. Leaders must communicate effectively and inspire everyone to adopt the vision."
#               },
#               {
#                 "mobile_summary_number": "5",
#                 "mobile_summary_final": "Effective leaders are approachable, enthusiastic, and possess strong communication skills. They're adept at delegating and dedicated to both customer and business success. Honesty in product pricing and business dealings is paramount."
#               },
#               {
#                 "mobile_summary_number": "6",
#                 "mobile_summary_final": "Finally, motivating your team involves attentive listening, providing timely feedback, and recognizing good work explicitly. Feedback should be constructive and private. Celebrate achievements openly to encourage continued excellence. More on this soon!"
#               },
#               {
#                 "mobile_summary_number": "7",
#                 "mobile_summary_final": "Congratulations, you have completed #PERCENT% of the successful ae operations, leadership and entrepreneurship category 👍"
#               }
#             ]
#           }
#         },
#         "swahili": {
#           "Habari! Leo tutajifunza  ujuzi muhimu wa masiriamali na uongozi unaohitajika kwa mafanikio yako. Tutafafanua nini maana ya ujasiriamali, tujadili sifa kuu za kijasiriamali, na kuelekea katika maendeleo ya uongozi. Twende tukaanze!": {
#             "Kila somo jipya unalokumbatia ni kichocheo cha mafanikio ya baadaye katika biashara ya kilimo—endelea kuchochea shauku na ari yako.": [
#               {
#                 "mobile_summary_number": "1",
#                 "mobile_summary_final": "Ujasiriamali unahusisha kutambua fursa za soko, kupanga mikakati, kuandaa rasilimali, na kuwekeza kwa manufaa ya muda mrefu. Mjasiriamali huanzisha biashara, huchukua hatari, na kulenga mafanikio kwa kuleta maoni mapya na ya kibunifu kuwa hai."
#               },
#               {
#                 "mobile_summary_number": "2",
#                 "mobile_summary_final": "Kama wajasiriamali, sifa muhimu ni pamoja na: kutafuta kwa bidii fursa za ukuaji, kuweka kipaumbele  ufanisi, kudai ubora, na kuhakikisha ufanisi wa gharama. Pia wana taarifa, ni wa kimkakati, wawekezaji wa malengo, wapangaji, na ni wenye subira."
#               },
#               {
#                 "mobile_summary_number": "3",
#                 "mobile_summary_final": "Wajasiriamali  wazuri wana ujasiri na ni wasikilizaji wazuri, wakiwa na uelewa wa mahitaji ya wateja na wauzaji. Wao ni wenye maamuzi na uwezo wa kufanya maamuzi magumu, wakihamasisha wengine kuelekea mafanikio. Kuchukua hatari na uwezo wa kushawishi pia ni muhimu."
#               },
#               {
#                 "mobile_summary_number": "4",
#                 "mobile_summary_final": "Tukigeukia katika  uongozi, kiongozi mzuri huunda maono ya baadaye yanayoleta msukumo, huhamasisha ushiriki, husimamia utekelezaji wa maono, na huwanoa timu yake . Viongozi lazima waweze kuwasiliana kwa ufanisi na kuwahamasisha wote kupokea maono hayo."
#               },
#               {
#                 "mobile_summary_number": "5",
#                 "mobile_summary_final": "Viongozi wenye ufanisi ni wawazi, wenye shauku, wanafikikika ,na wana uwezo mkubwa wa mawasiliano. Wanaujuzi wa kuweka majukumu kwa wengine na wamejitolea kwa mafanikio ya wateja na biashara. Uaminifu katika bei ya bidhaa na miamala ya biashara ni jambo la muhimu sana."
#               },
#               {
#                 "mobile_summary_number": "6",
#                 "mobile_summary_final": "Hatimaye, kuhamasisha kikosi chako kunahusisha kusikiliza kwa makini, kutoa maoni kwa wakati unaofaa, na kutambua kazi nzuri kwa dhahiri. Maoni yanapaswa kuwa ya kujenga na ya faragha. Sherehekea mafanikio kwa uwazi ili kuhamasisha ubora endelevu. Tutazungumza zaidi kuhusu hili hivi karibuni!"
#               },
#               {
#                 "mobile_summary_number": "7",
#                 "mobile_summary_final": "Hongera, umekamilisha #PERCENT% ya aina ya Operesheni za Wajasiriamali wa Kilimo zilizofanikiwa ,Uongozi na Ujasiriamali 👍"
#               }
#             ]
#           }
#         }
#       }
#     }
#   }
# }
# Combined content saved to blf_mobile_intaigent_combined.json
